# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print(len(data))
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)

  print('embed', embed.shape)
  # Compute the softmax loss, using a sample of the negative labels each time.

  print('weights', softmax_weights)
  print('biases', softmax_biases)
  print('labels', train_labels.shape)
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# embed (128, 128)
# weights Tensor("Variable_1/read:0", shape=(50000, 128), dtype=float32, device=/device:CPU:0)
# biases Tensor("Variable_2/read:0", shape=(50000,), dtype=float32, device=/device:CPU:0)
# labels (128, 1)

# %%
## num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    #print('data', batch_data.shape)
    #print('labels', batch_labels.shape)
#     print('data', batch_data[:5])
#     print('labels', batch_labels[:5])
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    
#     print('train', batch_data.shape)
#     print('label', batch_labels.shape)
    #print('emb', emb[0])
    #print('embing', embing[batch_data[0]])
#     print(emb[0] == embing[batch_data[0]])
    
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.975701
# Nearest to see: kryptonians, brainwashing, disappears, pinscher, spousal, jill, chih, hopped,
# Nearest to may: pendergast, chez, liguria, others, adapter, disfavor, cody, parent,
# Nearest to five: witherspoon, fluorescent, nuremberg, republished, hagen, spree, affiliated, awakened,
# Nearest to in: phocas, rawls, basileus, londoners, slashdot, transmissions, certainty, adorned,
# Nearest to UNK: cytosine, euphonium, carib, agriculture, ullman, crumb, archiving, strange,
# Nearest to if: dialling, langle, emphatically, tomorrowland, lax, putsch, reject, unknowingly,
# Nearest to united: full, princeto, venerable, biotechnology, wray, kazan, xli, tian,
# Nearest to seven: tempestuous, smoothed, appendicitis, disrupts, sinatra, bomis, inspectors, theosophy,
# Nearest to it: undeniably, ethiopic, walkways, masturbating, terran, comply, ava, firewire,
# Nearest to were: consecrate, nicely, peruvian, racial, tree, miggins, closely, childe,
# Nearest to be: repackaged, asclepius, navigate, frs, lunch, thant, formaldehyde, repercussions,
# Nearest to three: enjoyable, senators, consultancy, cpm, agarose, megadeth, deprogramming, refered,
# Nearest to between: smpte, digs, ringo, pa, deflection, adenosine, citro, guys,
# Nearest to over: mjs, dios, harmattan, tyre, searched, invest, uruguayan, ciliates,
# Nearest to these: kingfishers, unrelated, halves, our, adaptations, consistory, lichens, deo,
# Nearest to often: swami, irene, pathfinder, vicars, processing, cup, ep, wakizashi,
# Average loss at step 2000: 4.374908
# Average loss at step 4000: 3.867877
# Average loss at step 6000: 3.792126
# Average loss at step 8000: 3.688831
# Average loss at step 10000: 3.615145
# Nearest to see: kryptonians, pinscher, warehouses, fluctuation, multiplier, brainwashing, thus, jill,
# Nearest to may: can, pva, others, rosamund, parent, would, sheer, longhorn,
# Nearest to five: eight, six, four, seven, three, nine, zero, two,
# Nearest to in: of, on, at, for, deliberation, and, with, from,
# Nearest to UNK: romantics, oaks, mediawiki, mapmaking, peano, audi, kinder, eastwood,
# Nearest to if: jell, do, could, crystallographic, dialling, emphatically, expedient, that,
# Nearest to united: full, kazan, kipper, same, xli, national, venerable, health,
# Nearest to seven: six, five, eight, three, four, nine, zero, two,
# Nearest to it: he, this, which, they, not, there, she, that,
# Nearest to were: are, was, had, peruvian, preferences, woodwind, byrne, galtieri,
# Nearest to be: have, was, javan, as, trillion, discover, bodybuilder, pea,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to between: with, smpte, pa, ringo, digs, guys, lusignan, merz,
# Nearest to over: mjs, disqualification, invest, akademie, attorney, joey, sparsely, nobel,
# Nearest to these: our, parsecs, grandsons, street, those, kingfishers, completeness, arise,
# Nearest to often: also, not, processing, cup, veterinary, swami, which, moria,
# Average loss at step 12000: 3.607737
# Average loss at step 14000: 3.571307
# Average loss at step 16000: 3.409195
# Average loss at step 18000: 3.459543
# Average loss at step 20000: 3.539203
# Nearest to see: multiplier, shawn, brainwashing, fluctuation, tomb, spinster, ampersand, jill,
# Nearest to may: can, would, must, will, should, could, cannot, might,
# Nearest to five: six, seven, four, three, eight, zero, two, nine,
# Nearest to in: at, on, with, during, among, logged, ngo, banded,
# Nearest to UNK: agriculture, saint, iris, langerhans, reduplication, mexicana, iceland, beatification,
# Nearest to if: until, jell, where, do, though, when, but, expedient,
# Nearest to united: xli, same, venerable, national, southwards, gimlin, maximum, kazan,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to it: he, this, there, which, she, they, not, fertilizer,
# Nearest to were: are, was, have, had, is, be, when, jennifer,
# Nearest to be: have, is, was, been, were, discover, by, javan,
# Nearest to three: six, four, seven, five, two, eight, zero, one,
# Nearest to between: with, ringo, smpte, digs, since, from, chlamydia, goddess,
# Nearest to over: circa, joey, disqualification, dividend, sparsely, polybius, voices, attorney,
# Nearest to these: many, those, some, our, grandsons, all, parsecs, they,
# Nearest to often: also, generally, sometimes, now, still, which, widely, veterinary,
# Average loss at step 22000: 3.503632
# Average loss at step 24000: 3.489864
# Average loss at step 26000: 3.480012
# Average loss at step 28000: 3.477745
# Average loss at step 30000: 3.500151
# Nearest to see: multiplier, list, include, spinster, aeolian, jill, unexplained, but,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to five: four, seven, eight, six, three, zero, nine, two,
# Nearest to in: at, during, under, ngo, on, from, among, deliberation,
# Nearest to UNK: accounts, kohanim, et, romantics, squirt, albuquerque, academic, mexicana,
# Nearest to if: when, where, though, jell, but, although, until, advocates,
# Nearest to united: xli, southwards, same, venerable, gimlin, wray, maximum, national,
# Nearest to seven: eight, five, four, nine, six, three, zero, two,
# Nearest to it: he, there, this, she, they, fertilizer, not, which,
# Nearest to were: are, was, have, had, be, being, is, by,
# Nearest to be: been, have, become, are, is, was, were, being,
# Nearest to three: four, five, seven, two, eight, six, nine, zero,
# Nearest to between: with, since, smpte, chlamydia, guys, lately, in, ringo,
# Nearest to over: circa, off, disqualification, akademie, syntax, joey, dividend, resume,
# Nearest to these: many, some, they, those, all, various, both, our,
# Nearest to often: still, also, sometimes, generally, now, widely, usually, typically,
# Average loss at step 32000: 3.502628
# Average loss at step 34000: 3.496479
# Average loss at step 36000: 3.463175
# Average loss at step 38000: 3.298915
# Average loss at step 40000: 3.428454
# Nearest to see: list, include, multiplier, but, unexplained, souk, stone, jonathan,
# Nearest to may: can, would, will, must, could, should, might, cannot,
# Nearest to five: seven, six, eight, four, three, nine, zero, two,
# Nearest to in: during, on, delicate, of, at, from, gini, journalism,
# Nearest to UNK: et, hypoglycemia, b, tubes, de, c, d, overturned,
# Nearest to if: when, where, though, until, jell, string, is, advocates,
# Nearest to united: xli, venerable, southwards, gimlin, wray, invention, amathus, arthritis,
# Nearest to seven: five, eight, nine, six, three, four, zero, one,
# Nearest to it: he, there, she, this, they, not, still, now,
# Nearest to were: are, have, was, had, be, while, been, hoplites,
# Nearest to be: have, been, is, become, refer, being, inert, try,
# Nearest to three: seven, five, four, six, two, eight, nine, zero,
# Nearest to between: with, smpte, ringo, commits, since, through, chlamydia, lately,
# Nearest to over: akademie, circa, about, earthworks, hardback, resume, polybius, containing,
# Nearest to these: some, many, they, those, several, such, various, which,
# Nearest to often: still, sometimes, generally, usually, widely, commonly, also, typically,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-664e55463c60> in <module>()
#      13 #     print('labels', batch_labels[:5])
#      14     feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
# ---> 15     _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#      16
#      17 #     print('train', batch_data.shape)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      #labels[i * num_skips + j, 0] = buffer[target]
      labels[i * num_skips + j, ] = buffer[targ]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-233556660dca> in <module>()
#      30 for num_skips, skip_window in [(2, 1), (4, 2)]:
#      31     data_index = 0
# ---> 32     batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
#      33     print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
#      34     print('    batch:', [reverse_dictionary[bi] for bi in batch])
#
# <ipython-input-5-233556660dca> in generate_batch(batch_size, num_skips, skip_window)
#      21       batch[i * num_skips + j] = buffer[skip_window]
#      22       #labels[i * num_skips + j, 0] = buffer[target]
# ---> 23       labels[i * num_skips + j, ] = buffer[targ]
#      24     buffer.append(data[data_index])
#      25     data_index = (data_index + 1) % len(data)
#
# NameError: global name 'targ' is not defined

# %%
start = 0
def gen(batch_size, window):
    global start
    global batch
    labels = None
    i = start
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    

    length = min(len(data)-1, start+batch_size)-start + 1
    labels=[]
    while i < start + batch_size and i < len(data):
        print(i)
        left = max(0, i - window)
        right = min(i + window, len(data) - 1)
#       length = min(len(data)-1, start+batch_size)-start + 1
        #print(left, right)
        #labels = np.ndarray(shape=(length, right-left+1), dtype=np.int32)
        
        batch[i-start] = data[i]
        #rid self?
        #print('i - start', i-start)
        labels.append(data[left:right+1])
        i = i + 1
    start = i
    return batch, np.array(labels)

# %%
gen(3, 2)
# Out:
# 0
# 1
# 2
# (array([5239, 3084,   12], dtype=int32),
#  array([[5239, 3084, 12], [5239, 3084, 12, 6], [5239, 3084, 12, 6, 195]], dtype=object))

# %%
data_index = 0

def generate_bag(batch_size, skip_window):
    global data_index
    total = 2 * skip_window + 1
    batch = np.ndarray(shape=(batch_size, total-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque()
    for _ in range(total):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        blist = list(buffer)
        # label @center
        labels[i, 0] = blist.pop(skip_window)
        batch[i] = blist
        buffer.append(data[data_index])
        buffer.popleft()
        data_index = (data_index + 1) % len(data)
    return batch, labels

# ob, ol = generate_bag(batch_size, 2)
# print(ob.shape)
# print(ol.shape)
# print('ob', ob[0])
# print('ol', ol[0])

# ob, ol = generate_bag(batch_size, 2)
# print(ob.shape)
# print(ol.shape)
# print('ob', ob[0])
# print('ol', ol[0])


# for num_skips, skip_window in [(2, 1), (4, 2)]:
#     data_index = 0
#     batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
#     print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
#     print('    batch:', [reverse_dictionary[bi] for bi in batch])
#     print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
#skip_window = 1 # How many words to consider left and right.
skip_window = 3
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  #train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.

#   avelist = []
#   for i in range(batch_size):
#         ave = tf.reshape(tf.reduce_mean(tf.nn.embedding_lookup(embeddings, train_dataset[i]), 0), [1, embedding_size])
#         #print(ave.shape)
#         avelist.append(ave)
  #ave_embed = tf.concat(avelist, 0)
    
#   print('ave_embed', ave_embed.shape)
#   print('weights', softmax_weights)
#   print('biases', softmax_biases)
#   print('labels', train_labels.shape)
    
  print(embed.shape)
  print(tf.reduce_mean(embed, 1).shape)
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_mean(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# (128, 6, 128)
# (128, 128)

# %%
num_steps = 100001

# def average(data, size, embeds):
#     avearr = np.ndarray(shape=(size, embedding_size), dtype=np.int32)
#     for i in range(size):
#         ave = np.mean(tf.nn.embedding_lookup(embeds, data[i]), 0)
#         avearr[i] = ave
#     return avearr

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  print('skip', skip_window)
  for step in range(num_steps):
    batch_data, batch_labels = generate_bag(
      batch_size, skip_window)
#     print(batch_data.shape)
#     print(batch_labels.shape)
    #batch_data = average(batch_data, batch_size, embeddings)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# skip 3
# Average loss at step 0: 7.954287
# Nearest to his: lounge, method, off, going, snowflake, pathways, hold, leroy,
# Nearest to with: denoting, dawson, semipalatinsk, abbreviate, flatness, cleansed, constructs, weakest,
# Nearest to american: berenson, interaction, sector, diffuses, boil, berglin, plunkett, privately,
# Nearest to used: fsln, hitherto, correlate, cocoon, abimelech, edvac, shigeru, posthumus,
# Nearest to be: citizen, romain, roc, volkov, sheepdog, ousting, reductionism, cms,
# Nearest to four: cdp, oversees, figaro, goin, bodyguards, meissen, edo, conspirators,
# Nearest to it: discouraging, hipc, donny, lomax, focus, getting, intifada, trist,
# Nearest to than: corr, ghazi, foundered, tamil, bicarbonate, ahead, inns, budgeted,
# Nearest to they: declaration, malthusian, televisions, assess, loan, corners, michel, kibbutz,
# Nearest to these: hawk, swings, heysel, oxymoron, stanshall, testicles, temples, gable,
# Nearest to called: plaza, constructivism, mitch, baronies, dopant, hler, northside, lathes,
# Nearest to in: hang, fyodorovna, lakeshore, goguryeo, editing, papier, possum, huang,
# Nearest to also: breaking, phytoplankton, mcelroy, cottingley, polyethylene, admittance, amenities, archimedean,
# Nearest to a: stale, launceston, appalachians, vastly, cicero, hurst, illinois, sincerity,
# Nearest to no: precipitated, namco, summands, enigmas, regain, knowledge, collins, unicameral,
# Nearest to war: laodiceans, ostara, insist, metellus, tes, acorns, porpoise, academia,
# Average loss at step 2000: 4.216307
# Average loss at step 4000: 3.756712
# Average loss at step 6000: 3.592880
# Average loss at step 8000: 3.455654
# Average loss at step 10000: 3.461803
# Nearest to his: its, their, going, appendage, bhutan, hold, her, gentlemen,
# Nearest to with: denoting, ahaz, psychologists, semipalatinsk, cells, cvs, sheila, moonshine,
# Nearest to american: jeffreys, saito, privately, inflammation, sig, diffuses, losing, prevention,
# Nearest to used: confucian, rivets, fsln, pedestrian, outgoing, sextus, posthumus, recalls,
# Nearest to be: have, reductionism, citizen, rb, romain, cms, tarleton, we,
# Nearest to four: three, km, ledoux, mortis, suny, figaro, alessandro, cdp,
# Nearest to it: he, hipc, trist, cataracts, poetry, lomax, focus, reorganization,
# Nearest to than: corr, foundered, tamil, ghazi, waza, lovelock, ahead, or,
# Nearest to they: vicki, televisions, we, abc, some, sidewinder, he, vikings,
# Nearest to these: some, several, effects, robes, gable, illumination, yasser, hawk,
# Nearest to called: baronies, realistically, when, utc, mitch, ikeda, quantification, northside,
# Nearest to in: multiverse, hang, lakeshore, nashwaak, fyodorovna, randal, from, cooley,
# Nearest to also: phytoplankton, occured, what, breaking, mor, others, rtf, mapmaking,
# Nearest to a: an, this, the, accused, illinois, avenues, savvy, stale,
# Nearest to no: some, summands, real, it, colonization, knowles, nitrate, barry,
# Nearest to war: laodiceans, ostara, porpoise, mischievous, smuggled, essayist, jawaharlal, undertaker,
# Average loss at step 12000: 3.458679
# Average loss at step 14000: 3.424726
# Average loss at step 16000: 3.450585
# Average loss at step 18000: 3.400850
# Average loss at step 20000: 3.334013
# Nearest to his: their, her, its, s, appendage, going, bhutan, hold,
# Nearest to with: denoting, ahaz, semipalatinsk, sheila, sampson, flatness, moonshine, summing,
# Nearest to american: jeffreys, inflammation, privately, sig, saito, wavell, mariano, renown,
# Nearest to used: confucian, considered, uplifted, outgoing, given, fsln, appear, larsen,
# Nearest to be: describe, refers, have, rb, sheepdog, beyer, citizen, reductionism,
# Nearest to four: six, three, five, eight, km, seven, bormann, laureate,
# Nearest to it: he, this, she, hipc, poetry, dect, otters, cataracts,
# Nearest to than: tamil, foundered, corr, ahead, waza, ghazi, budgeted, lebrun,
# Nearest to they: we, vicki, you, televisions, these, he, corners, abc,
# Nearest to these: some, effects, several, they, yasser, other, words, robes,
# Nearest to called: ikeda, loophole, realistically, org, baronies, dazzling, mitch, approve,
# Nearest to in: hang, editing, lakeshore, nashwaak, alpina, fyodorovna, cooley, randal,
# Nearest to also: phytoplankton, occured, mor, darlington, bronchitis, mcelroy, gorgias, breaking,
# Nearest to a: another, an, the, pinus, any, vigilant, this, avenues,
# Nearest to no: some, any, summands, colonization, barry, another, nitrate, real,
# Nearest to war: laodiceans, ostara, porpoise, trade, academia, smuggled, essayist, jawaharlal,
# Average loss at step 22000: 3.367737
# Average loss at step 24000: 3.341164
# Average loss at step 26000: 3.337349
# Average loss at step 28000: 3.333450
# Average loss at step 30000: 3.293908
# Nearest to his: her, their, its, s, appendage, bhutan, going, him,
# Nearest to with: denoting, sheila, sampson, summing, ahaz, hayling, moonshine, weakest,
# Nearest to american: jeffreys, inflammation, privately, sig, practices, mariano, saito, renown,
# Nearest to used: considered, confucian, referred, called, fsln, outgoing, correlate, uplifted,
# Nearest to be: describe, refers, refer, being, beyer, provide, happen, orchards,
# Nearest to four: six, three, five, seven, eight, km, pesos, two,
# Nearest to it: he, this, she, yorkist, intifada, dect, poplar, hipc,
# Nearest to than: tamil, corr, foundered, budgeted, sebald, optimal, berger, ahead,
# Nearest to they: we, you, he, televisions, corners, vicki, eligibility, abc,
# Nearest to these: some, several, effects, other, drusilla, words, certain, which,
# Nearest to called: considered, used, ikeda, loophole, realistically, rna, softly, dazzling,
# Nearest to in: hang, within, nashwaak, throughout, monde, randal, editing, alpina,
# Nearest to also: occured, phytoplankton, mor, reuter, fpgas, gorgias, bronchitis, mcelroy,
# Nearest to a: another, every, turkish, any, vigilant, mainly, the, reloaded,
# Nearest to no: any, some, subtitles, another, regain, rotating, colonization, summands,
# Nearest to war: laodiceans, ostara, porpoise, essayist, mischievous, academia, trade, jawaharlal,
# Average loss at step 32000: 3.168018
# Average loss at step 34000: 3.269823
# Average loss at step 36000: 3.249935
# Average loss at step 38000: 3.211656
# Average loss at step 40000: 3.266979
# Nearest to his: her, their, s, its, appendage, our, bhutan, him,
# Nearest to with: denoting, weakest, sheila, ahaz, summing, hayling, moonshine, semipalatinsk,
# Nearest to american: jeffreys, america, inflammation, privately, courted, renown, sig, saito,
# Nearest to used: referred, use, fsln, given, seen, called, considered, available,
# Nearest to be: being, refer, describe, refers, happen, beyer, lading, win,
# Nearest to four: six, five, three, seven, eight, metres, unprotected, zero,
# Nearest to it: he, she, this, yorkist, ropes, intifada, poplar, hipc,
# Nearest to than: corr, tamil, foundered, optimal, budgeted, berger, sebald, sars,
# Nearest to they: we, you, he, corners, televisions, vicki, eligibility, biscuits,
# Nearest to these: some, certain, other, which, various, several, drusilla, fragmentation,
# Nearest to called: ikeda, considered, used, rna, loophole, softly, accomplishments, tsim,
# Nearest to in: within, fyodorovna, during, until, hang, randal, monde, editing,
# Nearest to also: occured, phytoplankton, mor, donut, unbelievers, marmoset, gorgias, fpgas,
# Nearest to a: another, every, unadorned, any, vigilant, the, accused, edu,
# Nearest to no: any, nothing, another, little, regain, resembling, excepted, colonization,
# Nearest to war: laodiceans, ostara, porpoise, trade, dynamism, technocracy, essayist, emperor,
# Average loss at step 42000: 3.274178
# Average loss at step 44000: 3.233642
# Average loss at step 46000: 3.222928
# Average loss at step 48000: 3.190107
# Average loss at step 50000: 3.156267
# Nearest to his: her, their, s, its, our, appendage, him, bhutan,
# Nearest to with: denoting, weakest, sheila, between, sampson, summing, moonshine, semipalatinsk,
# Nearest to american: jeffreys, renown, inflammation, sig, courted, moro, diffuses, saito,
# Nearest to used: use, referred, available, given, seen, considered, called, known,
# Nearest to be: being, refer, describe, happen, lead, refers, mean, provide,
# Nearest to four: five, six, three, seven, eight, two, unprotected, km,
# Nearest to it: he, she, this, yorkist, intifada, what, hipc, poplar,
# Nearest to than: optimal, tamil, or, budgeted, corr, berger, mix, sars,
# Nearest to they: we, you, he, corners, televisions, eligibility, these, biscuits,
# Nearest to these: some, certain, which, various, all, drusilla, other, several,
# Nearest to called: considered, used, ikeda, rna, tsim, dazzling, loophole, accomplishments,
# Nearest to in: within, until, during, editing, nashwaak, lakeshore, monde, throughout,
# Nearest to also: occured, unbelievers, fpgas, phytoplankton, gorgias, still, interplanetary, mor,
# Nearest to a: another, any, every, vigilant, fingered, the, accused, scavenging,
# Nearest to no: any, nothing, little, another, regain, excepted, colonization, enigmas,
# Nearest to war: laodiceans, porpoise, ostara, trade, dynamism, technocracy, mischievous, emperor,
# Average loss at step 52000: 3.165758
# Average loss at step 54000: 3.191614
# Average loss at step 56000: 3.090483
# Average loss at step 58000: 3.148580
# Average loss at step 60000: 3.134570
# Nearest to his: her, their, s, its, our, appendage, him, bhutan,
# Nearest to with: denoting, weakest, sheila, serfdom, southampton, between, summing, anglican,
# Nearest to american: jeffreys, renown, america, australian, moro, inflammation, sig, courted,
# Nearest to used: use, referred, given, available, called, seen, considered, known,
# Nearest to be: being, refer, happen, describe, lead, refers, taj, lading,
# Nearest to four: five, three, six, seven, eight, two, metres, million,
# Nearest to it: he, she, this, yorkist, intifada, what, poplar, hipc,
# Nearest to than: optimal, likely, berger, corr, budgeted, tamil, or, oratorios,
# Nearest to they: we, you, he, corners, televisions, these, themselves, eligibility,
# Nearest to these: some, which, certain, various, other, several, many, clever,
# Nearest to called: considered, used, rna, ikeda, dazzling, ob, tsim, loophole,
# Nearest to in: within, until, throughout, during, nashwaak, monde, lakeshore, fortification,
# Nearest to also: occured, gorgias, disambiguation, fpgas, unbelievers, phytoplankton, donut, statutes,
# Nearest to a: another, every, any, vigilant, fingered, comparable, scavenging, unadorned,
# Nearest to no: any, nothing, little, another, regain, enigmas, evangelistic, java,
# Nearest to war: porpoise, ostara, laodiceans, dynamism, trade, emperor, technocracy, jawaharlal,
# Average loss at step 62000: 3.102573
# Average loss at step 64000: 3.086214
# Average loss at step 66000: 3.044769
# Average loss at step 68000: 3.068113
# Average loss at step 70000: 3.110822
# Nearest to his: her, their, s, its, our, appendage, my, him,
# Nearest to with: between, denoting, sheila, weakest, shogunate, retarded, southampton, ahaz,
# Nearest to american: joe, jeffreys, australian, moro, renown, america, sig, italian,
# Nearest to used: use, referred, seen, considered, available, given, found, called,
# Nearest to be: being, refer, happen, describe, lead, remain, mean, refers,
# Nearest to four: five, six, three, seven, eight, two, zero, metres,
# Nearest to it: he, she, this, yorkist, what, intifada, methodists, poplar,
# Nearest to than: mix, tamil, budgeted, optimal, likely, or, berger, flushing,
# Nearest to they: we, you, he, corners, these, televisions, themselves, eligibility,
# Nearest to these: some, certain, which, various, other, several, irl, such,
# Nearest to called: considered, used, rna, ikeda, dazzling, pressing, ob, loophole,
# Nearest to in: within, throughout, multiverse, until, during, fyodorovna, outside, editing,
# Nearest to also: disambiguation, occured, gorgias, now, still, fpgas, phytoplankton, interplanetary,
# Nearest to a: another, every, any, vigilant, fingered, accused, comparable, anthropogenic,
# Nearest to no: any, nothing, enigmas, another, regain, little, evangelistic, colonization,
# Nearest to war: ostara, laodiceans, porpoise, trade, dynamism, mischievous, jawaharlal, steamers,
# Average loss at step 72000: 2.999280
# Average loss at step 74000: 3.110025
# Average loss at step 76000: 3.127913
# Average loss at step 78000: 3.079235
# Average loss at step 80000: 3.033639
# Nearest to his: her, their, s, its, our, appendage, my, whose,
# Nearest to with: denoting, between, weakest, sheila, retarded, ahaz, shogunate, serfdom,
# Nearest to american: australian, america, renown, italian, jeffreys, japanese, inflammation, moro,
# Nearest to used: use, referred, seen, available, designed, given, known, called,
# Nearest to be: being, refer, happen, describe, lead, remain, been, become,
# Nearest to four: six, five, three, seven, eight, zero, futurama, two,
# Nearest to it: he, she, this, yorkist, what, intifada, poplar, methodists,
# Nearest to than: mix, budgeted, optimal, tamil, berger, likely, flushing, sars,
# Nearest to they: we, you, he, corners, these, televisions, eligibility, themselves,
# Nearest to these: which, certain, other, some, various, several, irl, they,
# Nearest to called: considered, used, rna, dazzling, ikeda, ob, found, oaks,
# Nearest to in: within, throughout, until, during, randal, lakeshore, outside, editing,
# Nearest to also: disambiguation, occured, gorgias, fpgas, statutes, unbelievers, sarris, kiwi,
# Nearest to a: another, every, any, fingered, vigilant, anthropogenic, comparable, scavenging,
# Nearest to no: any, nothing, little, enigmas, another, regain, colonization, only,
# Nearest to war: ostara, porpoise, trade, laodiceans, dynamism, claw, mischievous, creep,
# Average loss at step 82000: 3.046911
# Average loss at step 84000: 3.087369
# Average loss at step 86000: 3.078487
# Average loss at step 88000: 2.983798
# Average loss at step 90000: 3.060831
# Nearest to his: her, their, its, s, our, my, your, him,
# Nearest to with: between, denoting, sheila, weakest, shogunate, retarded, serfdom, hayling,
# Nearest to american: america, renown, australian, italian, jeffreys, courted, canadian, americans,
# Nearest to used: use, referred, seen, available, designed, found, applied, called,
# Nearest to be: being, refer, happen, lead, remain, describe, newly, been,
# Nearest to four: five, six, three, seven, eight, two, averaged, fachhochschule,
# Nearest to it: he, she, this, yorkist, dect, methodists, intifada, poplar,
# Nearest to than: mix, budgeted, or, berger, tamil, flushing, optimal, oratorios,
# Nearest to they: we, you, he, corners, these, televisions, themselves, biscuits,
# Nearest to these: certain, which, other, various, some, several, different, they,
# Nearest to called: considered, used, rna, dazzling, ob, bis, pressing, ikeda,
# Nearest to in: within, throughout, until, during, outside, randal, huang, lakeshore,
# Nearest to also: disambiguation, fpgas, statutes, now, unbelievers, occured, still, sarris,
# Nearest to a: another, any, every, vigilant, comparable, accused, fingered, scavenging,
# Nearest to no: nothing, any, little, enigmas, regain, another, only, evangelistic,
# Nearest to war: ostara, porpoise, trade, laodiceans, mischievous, dynamism, claw, batter,
# Average loss at step 92000: 3.018993
# Average loss at step 94000: 2.976548
# Average loss at step 96000: 2.648084
# Average loss at step 98000: 2.825982
# Average loss at step 100000: 2.995195
# Nearest to his: her, their, its, s, our, my, appendage, idiosyncrasies,
# Nearest to with: between, retarded, sheila, denoting, weakest, morris, shogunate, savages,
# Nearest to american: joe, australian, canadian, renown, italian, jeffreys, british, america,
# Nearest to used: use, referred, seen, designed, applied, called, found, available,
# Nearest to be: being, happen, refer, remain, lead, describe, newly, have,
# Nearest to four: five, six, three, seven, eight, two, zero, futurama,
# Nearest to it: she, he, this, yorkist, what, intifada, ropes, dianetics,
# Nearest to than: mix, budgeted, likely, sars, jesse, oratorios, optimal, tamil,
# Nearest to they: we, you, he, these, televisions, she, corners, jens,
# Nearest to these: certain, which, some, various, other, several, they, many,
# Nearest to called: considered, used, rna, dazzling, found, referred, pressing, thalberg,
# Nearest to in: within, throughout, during, outside, nashwaak, huang, until, lakeshore,
# Nearest to also: disambiguation, now, unbelievers, gorgias, kiwi, fpgas, statutes, occured,
# Nearest to a: another, any, every, fingered, vigilant, scavenging, quintana, immersive,
# Nearest to no: nothing, any, little, regain, enigmas, another, excepted, only,
# Nearest to war: ostara, trade, laodiceans, champion, porpoise, dynamism, wars, mischievous,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
